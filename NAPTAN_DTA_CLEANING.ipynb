# %% [markdown]
# IMPORTING DATASETS
# naptan guide:
# https://www.gov.uk/government/publications/national-public-transport-access-node-schema/naptan-guide-for-data-managers

# %%
import geopandas as gpd 
import shapely 
import pathlib 
import pandas as pd

# %%
Scotland_Bus_Stops = pd.read_csv(
    '/Users/ericmarshall/Desktop/Hackathon datasets/ScotlandBusStops.csv',
    header=1
)
# Out:
# /var/folders/xh/120rhvzs2vjg8p4fsk_11tkh0000gn/T/ipykernel_54747/2044196111.py:1: DtypeWarning: Columns (2,21,22,23,24,25,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   Scotland_Bus_Stops = pd.read_csv(

# %% [markdown]
# EXPLORING DATA

# %%
print(Scotland_Bus_Stops.columns)
# Out:
# Index(['ATCOCode', 'NaptanCode', 'PlateCode', 'CleardownCode', 'CommonName',
#        'CommonNameLang', 'ShortCommonName', 'ShortCommonNameLang', 'Landmark',
#        'LandmarkLang', 'Street', 'StreetLang', 'Crossing', 'CrossingLang',
#        'Indicator', 'IndicatorLang', 'Bearing', 'NptgLocalityCode',
#        'LocalityName', 'ParentLocalityName', 'GrandParentLocalityName', 'Town',
#        'TownLang', 'Suburb', 'SuburbLang', 'LocalityCentre', 'GridType',
#        'Easting', 'Northing', 'Longitude', 'Latitude', 'StopType',
#        'BusStopType', 'TimingStatus', 'DefaultWaitTime', 'Notes', 'NotesLang',
#        'AdministrativeAreaCode', 'CreationDateTime', 'ModificationDateTime',
#        'RevisionNumber', 'Modification', 'Status'],
#       dtype='object')

# %%
Scotland_Bus_Stops
# Out:
#         ATCOCode  NaptanCode PlateCode  CleardownCode          CommonName  \
# 0      630020011  23627454.0       NaN            NaN            Road End
# 1      630020012  23627453.0       NaN            NaN            Road End
# 2      630020021  23627457.0       NaN            NaN   Bridgend Crescent
# 3      630020022  23629258.0       NaN            NaN   Bridgend Crescent
# 4      630020023  23629649.0       NaN            NaN   Bridgend Road End
# ...          ...         ...       ...            ...                 ...
# 50658   60101477  94729543.0       NaN            NaN          Grosabhagh
# 50659   60101484  94728585.0       NaN            NaN              School
# 50660   60101485  94729545.0       NaN            NaN            Road End
# 50661   60101486  94729237.0       NaN            NaN             Village
# 50662   60101487  94729238.0       NaN            NaN  Nicolson Institute
#
#        CommonNameLang ShortCommonName  ShortCommonNameLang  \
# ...

# %%
print(Scotland_Bus_Stops.columns)
# Out:
# Index(['ATCOCode', 'NaptanCode', 'PlateCode', 'CleardownCode', 'CommonName',
#        'CommonNameLang', 'ShortCommonName', 'ShortCommonNameLang', 'Landmark',
#        'LandmarkLang', 'Street', 'StreetLang', 'Crossing', 'CrossingLang',
#        'Indicator', 'IndicatorLang', 'Bearing', 'NptgLocalityCode',
#        'LocalityName', 'ParentLocalityName', 'GrandParentLocalityName', 'Town',
#        'TownLang', 'Suburb', 'SuburbLang', 'LocalityCentre', 'GridType',
#        'Easting', 'Northing', 'Longitude', 'Latitude', 'StopType',
#        'BusStopType', 'TimingStatus', 'DefaultWaitTime', 'Notes', 'NotesLang',
#        'AdministrativeAreaCode', 'CreationDateTime', 'ModificationDateTime',
#        'RevisionNumber', 'Modification', 'Status'],
#       dtype='object')

# %%
Scotland_Bus_Stops.head()       
Scotland_Bus_Stops.info()      
Scotland_Bus_Stops.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50663 entries, 0 to 50662
# Data columns (total 43 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ATCOCode                 50663 non-null  object
#  1   NaptanCode               50173 non-null  float64
#  2   PlateCode                11 non-null     object
#  3   CleardownCode            0 non-null      float64
#  4   CommonName               50663 non-null  object
#  5   CommonNameLang           0 non-null      float64
#  6   ShortCommonName          6872 non-null   object
#  7   ShortCommonNameLang      0 non-null      float64
#  8   Landmark                 47100 non-null  object
#  9   LandmarkLang             0 non-null      float64
#  10  Street                   49696 non-null  object
#  11  StreetLang               0 non-null      float64
#  12  Crossing                 0 non-null      float64
# ...

# %%
Scotland_Bus_Stops_GeoSpatial.columns
# Out:
# Index(['NaptanCode', 'Easting', 'Northing', 'CommonName', 'ATCOCode',
#        'LocalityName', 'CreationDateTime', 'ModificationDateTime', 'Status',
#        'StopType'],
#       dtype='object')

# %% [markdown]
# EXPORTING DESIRED COLUMNS

# %%
Scotland_Bus_Stops_GeoSpatial = Scotland_Bus_Stops[
    [
        'NaptanCode',
        'Easting',
        'Northing',
        'CommonName',
        'ATCOCode',
        'LocalityName',
        'CreationDateTime',
        'ModificationDateTime',
        'Status',
        'StopType',
    ]
]

# %% [markdown]
# DELETING NULL ROWS

# %%
Scotland_Bus_Stops_GeoSpatial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50663 entries, 0 to 50662
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   NaptanCode            50173 non-null  float64
#  1   Easting               50663 non-null  int64
#  2   Northing              50663 non-null  int64
#  3   CommonName            50663 non-null  object
#  4   ATCOCode              50663 non-null  object
#  5   LocalityName          50663 non-null  object
#  6   CreationDateTime      50663 non-null  object
#  7   ModificationDateTime  50660 non-null  object
#  8   Status                50663 non-null  object
#  9   StopType              50663 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 3.9+ MB

# %%
Scotland_Bus_Stops_GeoSpatial = Scotland_Bus_Stops_GeoSpatial.dropna()

# %%
Scotland_Bus_Stops_GeoSpatial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50170 entries, 0 to 50662
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   NaptanCode            50170 non-null  float64
#  1   Easting               50170 non-null  int64
#  2   Northing              50170 non-null  int64
#  3   CommonName            50170 non-null  object
#  4   ATCOCode              50170 non-null  object
#  5   LocalityName          50170 non-null  object
#  6   CreationDateTime      50170 non-null  object
#  7   ModificationDateTime  50170 non-null  object
#  8   Status                50170 non-null  object
#  9   StopType              50170 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 4.2+ MB

# %% [markdown]
# EXPORTING

# %%
# Saving to CSV 

Scotland_Bus_Stops_GeoSpatial_Cleaned.to_csv('/Users/ericmarshall/Desktop/Hackathon datasets/Scotland_Bus_Stops_Geospatial.csv', index=False)
